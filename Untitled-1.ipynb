# %%
student = {
    "name": "Ram",
    "age": 20,
    "faculty": "BCE"
}

# %%
print(student)
# Out:
# {'name': 'Ram', 'age': 20, 'faculty': 'BCE'}

# %%
student.pop("age")
# Out:
# 20

# %%
student.get("name")
# Out:
# 'Ram'

# %%
student.values()
# Out:
# dict_values(['Ram', 'BCE'])

# %%
del student["faculty"]

# %%
student.items()
# Out:
# dict_items([('name', 'Ram')])

# %%
"faculty" in student
# Out:
# False

# %%
len(student)
# Out:
# 1

# %%
"a" in student
# Out:
# False

# %%
for k in student:
    print(student)
# Out:
# {'name': 'Ram'}

# %%
for v in student.values():
    print(v)
# Out:
# Ram

# %%
for k,v in student.items():
    print(k,v)
# Out:
# name Ram

# %%
data={
    'name': ['bibek','nabil','nirajan'],
    'age': [20,22,23],
    'phone': ['9842','9709','9871']
}

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   phone   3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   3.000000
# mean   21.666667
# std     1.527525
# min    20.000000
# 25%    21.000000
# 50%    22.000000
# 75%    22.500000
# max    23.000000

# %%
df['name']
# Out:
# 0      bibek
# 1      nabil
# 2    nirajan
# Name: name, dtype: object

# %%
df[['name', 'age']]
# Out:
#       name  age
# 0    bibek   20
# 1    nabil   22
# 2  nirajan   23

# %%
df.iloc[0]
# Out:
# name     bibek
# age         20
# phone     9842
# Name: 0, dtype: object

# %%
df.loc[0, 'name']
# Out:
# 'bibek'

# %%
df[df['age'] > 80]
# Out:
# Empty DataFrame
# Columns: [name, age, phone]
# Index: []

# %%
df[(df['age'] > 20) & (df['phone'] > '9700')]
# Out:
#       name  age phone
# 1    nabil   22  9709
# 2  nirajan   23  9871

# %%
df['grade'] = ['a', 'b', 'c']

# %%
df['age'] = df['age'] + 5

# %%
df.loc[df['name']=='bibek','nabil'] = 95
